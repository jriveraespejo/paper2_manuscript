# %% [markdown]
# # The interplay of assessment factors in Dichotomous Comparative
#
# Judgments
#
# A Bayesian simulation-based power analysis exploring their impacts on the method’s reliability
#
# [Jose Manuel Rivera Espejo](https://www.uantwerpen.be/en/staff/jose-manuel-rivera-espejo_23166/) [![](data:image/png;base64,...)](https://orcid.org/0000-0002-3088-2783) (University of Antwerp)
# [Sven Maeyer](https://www.uantwerpen.be/en/staff/sven-demaeyer/) [![](data:image/png;base64,...)](https://orcid.org/0000-0003-2888-1631) (University of Antwerp)
# [Steven Gillis](https://www.uantwerpen.be/nl/personeel/steven-gillis/) (University of Antwerp)
# March 20, 2024
#
# (to do) …
#
# ## 1 Introduction

# %% [raw]
# <!-- [(citation needed)]{style="color:red;"} -->

# %% [raw]
# <!-- 1. What is comparative judgment? -->

# %% [markdown]
# In contemporary contexts, Thurstone’s law of comparative judgment ([1927](#ref-Thurstone_1927)) primarily refers to the method of *Dichotomous* Comparative Judgment (DCJ). Within DCJ, a judge assesses the relative manifestation of a trait within a pair of stimuli. This results in a dichotomous value indicating which stimulus appears to possess a higher degree of the trait ([Pollitt 2012a](#ref-Pollitt_2012a), [2012b](#ref-Pollitt_2012b)). Following multiple rounds of pairwise comparisons made by different judges, an outcome vector is produced. Typically, this vector is modeled using the Bradley-Terry-Luce model (BTL model, [Bradley and Terry 1952](#ref-Bradley_et_al_1952); [Luce 1959](#ref-Luce_1959); [Pollitt 2012a](#ref-Pollitt_2012a)). The set of latent variables produced by the model can then be utilized, for example, to rank the stimuli from lowest to highest, or to assess the impact of certain characteristics of the stimuli on their position in the ranking.

# %% [raw]
# <!-- 2. in what has been applied on?, and where is the gap? -->

# %% [markdown]
# DCJ has proven effective in assessing competences and traits predominantly within the educational realm, as demonstrated by the works of Pollitt ([2012b](#ref-Pollitt_2012b)), Bartholomew et al. ([2018](#ref-Bartholomew_et_al_2018)), van Daal et al. ([2019](#ref-vanDaal_et_al_2016)) Lesterhuis ([2018](#ref-Lesterhuis_2018)), and Bartholomew and Williams ([2020](#ref-Bartholomew_et_al_2020)). However, its application transcends education, as exemplified by the work of Boonen, Kloots, and Gillis ([2020](#ref-Boonen_et_al_2020)). The methodology has also evolved to include multiple, as opposed to pairwise comparisons ([Luce 1959](#ref-Luce_1959); [Plackett 1975](#ref-Placket_1975)) and to accommodate comparisons with ordinal outcomes ([Tutz 1986](#ref-Tutz_1986); [Agresti 1992](#ref-Agresti_1992)). Overall, research suggests that DCJ offers an alternative and efficient approach to measurement and evaluation, characterized by its reliability and validity ([Lesterhuis 2018](#ref-Lesterhuis_2018); [van Daal 2020](#ref-vanDaal_2020); [Marshall et al. 2020](#ref-Marshall_et_al_2020)). Nevertheless, considering the method’s sophistication, there has been limited investigation about the interplay of the different assessment factors and their contribution to the method’s reliability.

# %% [raw]
# <!-- 3. What are the factors behind DCJ? -->

# %% [markdown]
# According to Verhavert et al. ([2019](#ref-Verhavert_et_al_2019)) and van Daal ([2020](#ref-vanDaal_2020)), several assessment factors interplay and contribute to the reliability of the DCJ method. These factors include the number of stimuli, the characteristics of the stimuli, their *proximity* in terms of the assessed trait, the number of comparison per stimulus, and the pairing algorithm used. Furthermore, since the method relies on judges’ assessments, the number of judges, the characteristics of judges, their *discrimination* abilities, and the number of comparisons per judge also play pivotal roles. Additionally, in cases where the stimuli represent sub-units (e.g., objects) from higher-levels units (e.g., subjects), then the number of units, the characteristics of the units, and their *proximity* in terms of the trait can also significantly influence the assessment outcome.
#
# The research of Boonen, Kloots, and Gillis ([2020](#ref-Boonen_et_al_2020)) offers a clear illustration of these factors and their interplay in a DCJ procedure. In their study, the authors evaluated the *overall perceived speech quality* (i.e., the trait) using six utterances (objects), each originating from $21$ children (subjects). The utterances were derived from an imitation task, while the children were evenly distributed across three groups: those with cochlear implants, those with hearing aids, and normal hearing children. To establish pairwise comparisons for the $126$ stimuli, a random pairing algorithm was employed, with $20$ comparisons per stimulus. Lastly, a total of $60$ listeners (judges) evaluated $65$ pairs of stimuli. The judges were equally selected from three distinct groups, each possessing varying degrees of experience with the speech of hearing-impaired children: audiologists, primary school teachers and inexperienced listeners. Ultimately, the authors were interested in assessing if there were differences in the *overall perceived speech quality* between groups of subjects and judges.

# %% [raw]
# <!-- 4. Where is the gap? -->

# %% [markdown]
# Previous studies have primarily focused on examining the individual impact of the different assessment factors on the reliability of DCJ. For instance, Bramley ([2015](#ref-Bramley_2015)) conducted a simulation-based study to investigate the effects of using random versus adaptive pairing algorithms on the Scale Separation Reliability (SSR, [Pollitt 2012b](#ref-Pollitt_2012b)). In a similar vein, Bramley and Vitello ([2019](#ref-Bramley_et_al_2019)) explored the influence of adaptive algorithms on the SSR using autobiographical essays from candidates in an English Language course, where the essays constituted half of the total marks for the final exam. In contrast, Verhavert et al. ([2019](#ref-Verhavert_et_al_2019)) conducted a meta-analysis examining the individual effects of various assessment factors on the SSR, including the number of stimuli, the format of stimuli, the number of comparisons per stimulus, the number of judges, the judges’ expertise, and feedback. Crompvoets, Béguin, and Sijtsma ([2022](#ref-Crompvoets_et_al_2022)) then examined through a simulation study how variations in the number of comparisons per stimulus affect the bias and stability of SSR components. Additionally, van Daal et al. ([2017](#ref-vanDaal_et_al_2017)) and Gijsen et al. ([2021](#ref-Gijsen_et_al_2021)) explored the moderating role of judges’ decision accuracy on the perceived complexity when comparing two stimuli. However, to the best of the author’s knowledge, there has been no systematic investigation into how different relevant assessment factors interact and what is their collective effect on the reliability of the DCJ method.

# %% [raw]
# <!-- 5. Solution to the gap -->

# %% [markdown]
# This study aims to address this gap by conducting a Bayesian simulation-based power analysis, following the Identification-Estimation flowchart outlined by McElreath ([2020](#ref-McElreath_2020)) and Neal ([2020](#ref-Neal_2020)). First, it defines the different targets of inference (i.e., the *estimands*), which are articulated through three research questions, over which the reliability of the DCJ method is evaluated. Subsequently, a *scientific model* for the DCJ procedure is constructed. These models describe the causal assumptions and mechanisms underlying the system, and facilitate inferences about causal relationships from data ([Hitchcock 2023](#ref-Hitchcock_2023)). To aid in the translation and visualization of the assumption underlying the DCJ procedure, Directed Acyclic Graphs (DAG) and Structural Causal Models (SCM) ([Pearl 2009](#ref-Pearl_2009); [Pearl, Glymour, and Jewell 2016](#ref-Pearl_et_al_2016); [Cinelli, Forney, and Pearl 2022](#ref-Cinelli_et_al_2021)) are employed. Next, an *estimator* in the form of a statistical model is utilized to derive an *statistical estimand* for the various targets of inference. Bayesian statistical method offer an intuitive approach to translate scientific models into probabilistic estimators. Finally, employing multiple simulated datasets for different combinations of the relevant assessment factors, the study generates multiple *estimates* for the statistical estimands. Notably, the statistical estimands in simulated data are known, consequently, the study can assess the DCJ reliability by evaluating the *proximity* to these estimands to the generated estimates. This final step resembles a power analysis. Ultimately, the outcomes of this study will inform the planning of DCJ experiments and hold significance for researchers or analysts involved in education and assessment procedures who implement DCJ methodologies.
#
# ## 2 Theoretical framework
#
# In order to evaluate the reliability of the DCJ method, first the study need to define certain terminology. This study uses the Identification-Estimation flowchart ([McElreath 2020](#ref-McElreath_2020); [Neal 2020](#ref-Neal_2020)). The flowchart illustrates the process of moving from a target (causal) *estimand* to a corresponding *estimate*, through identification and estimation (<a href="#fig-IEflowchart" class="quarto-xref">Figure 1</a>). An *estimand* is the target of inference of the quantity that we want to estimate. An *estimate* is an approximation of the *estimand*, which is obtained by using data. Moreover, identification refers to the process of moving from a (causal) *estimand* to an equivalent *statistical estimand*, and estimation refers to the process of moving from a *statistical estimand* to an *estimate*.

# %%
# Out:
# <svg width="384" height="384" viewbox="0.00 0.00 269.87 188.00" xmlns="http://www.w3.org/2000/svg" xlink="http://www.w3.org/1999/xlink" style="; max-width: none; max-height: none">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>IE</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-184 265.87,-184 265.87,4 -4,4"></polygon>
# <!-- A -->
# <g id="node1" class="node">
# <title>A</title>
# <polygon fill="none" stroke="black" points="123.61,-180 3.99,-180 3.99,-144 123.61,-144 123.61,-180"></polygon>
# <text text-anchor="middle" x="63.8" y="-157.8" font-family="Times,serif" font-size="14.00">(Causal) Estimand</text>
# </g>
# <!-- C -->
# <g id="node3" class="node">
# <title>C</title>
# <polygon fill="none" stroke="black" points="127.4,-108 0.2,-108 0.2,-72 127.4,-72 127.4,-108"></polygon>
# <text text-anchor="middle" x="63.8" y="-85.8" font-family="Times,serif" font-size="14.00">Statistical Estimand</text>
# </g>
# ...

# %% [raw]
# <!-- ![Identification-Estimation workflow](images/DCJ_DAG.tex) -->

# %% [markdown]
# ### 2.1 Research questions and their estimands

# %% [raw]
# <!-- **Research question 1** is interested in *which factors have an impact on the power to make comparisons between subjects' traits, with $95\%$ ($1-\alpha$) confidence?* (RQ1), when we want to compare: two random subjects, or one random subject versus a reference subject. Consequently the parameter of interest is $\theta_{i} - \theta_{j}$. -->

# %% [raw]
# <!-- Considering the results of **RQ1**, **Research question 2a** is interested in *which factors have an impact on the power to make comparisons of the average trait between groups of subjects / objects, with $95\%$ ($1-\alpha$) confidence?* (RQ2a). Consequently, the parameters of interest will be the $\beta_{X}$ or $\beta_{Y}$, if $X$ or $Y$ define two or more groups (or interactions). -->

# %% [raw]
# <!-- Considering the results of **RQ1**, **Research question 2b** is interested in *which factors have an impact on the power of covariates' regression parameters on the trait of subjects / objects, with $95\%$ ($1-\alpha$) confidence?* (RQ2b). Consequently, the parameters of interest will be the $\beta_{X}$ or $\beta_{Y}$, if $X$ or $Y$ define a continuous covariate. -->

# %% [raw]
# <!-- Considering the results of **RQ1**, **Research question 3a** is interested in *which factors have an impact on the power to make comparisons of the average "discrimination" ability between groups of judges, with $95\%$ ($1-\alpha$) confidence?}* (RQ3a). Consequently, the parameters of interest will be the $\beta_{Z}$ or $\beta_{Y}$, if $Z$ define two or more groups (or interactions). -->

# %% [raw]
# <!-- Considering the results of **RQ1**, **Research question 3b** is interested in *which factors have an impact on the power of covariates' regression parameters from covariates on the judgment ability of judges, with $95\%$ ($1-\alpha$) confidence?* (RQ3b). Consequently, the parameters of interest will be the $\beta_{Z}$, if $Z$ define a continuous covariate. -->

# %% [raw]
# <!-- For **RQ1** the factors of interest will be: -->

# %% [raw]
# <!-- 1. Number of objects per subject ($R_{i}$) -->

# %% [raw]
# <!-- 2. Number of comparisons per object -->

# %% [raw]
# <!-- 3. Variability of objects within each subject ($\sigma_{r_{i}}$) -->

# %% [raw]
# <!-- 4. Number of judges ($K$) -->

# %% [raw]
# <!--     indirectly determined by the number of comparison per judge, see \cite{Lawson_2015}, p. 263-264) -->

# %% [raw]
# <!-- 5. Judges' "discrimination" ability ($\gamma_{k}$) -->

# %% [raw]
# <!-- 6. Trait difference size between subjects ($\theta_{i} - \theta_{j}$) -->

# %% [raw]
# <!-- **RQ1** will not investigate the following factors: -->

# %% [raw]
# <!-- 1. Pairing algorithm (see \cite{Bramley_2015}). -->

# %% [raw]
# <!--       We will use a random algorithm (Balanced Incomplete Block design, BIB \cite{Lawson_2015})  -->

# %% [raw]
# <!-- 2. Number of comparisons per judge,  -->

# %% [raw]
# <!--       we assign the maximum number of comparison physically possible per judge, i.e., a fixed value (although, this is task specific)  -->

# %% [raw]
# <!-- 3. Format of the assessed object (see \cite{Verhavert_2018})  -->

# %% [raw]
# <!--     It is indirectly investigated in \textit{RQ2a} and \textit{RQ2b} -->

# %% [raw]
# <!-- 4. The variability proportion among group of subjects  -->

# %% [raw]
# <!--     It is indirectly investigated in \textit{RQ2a} and \textit{RQ2b}  -->

# %% [raw]
# <!-- For **RQ2a** the factors of interest will be: -->

# %% [raw]
# <!-- 1. Trait difference size between group of subjects / objects ($\beta_{X}$ or $\beta_{Y}$) -->

# %% [raw]
# <!-- 2. Number of subjects per group -->

# %% [raw]
# <!--     ($N_{g}$ where $g = 1, \dots, G$ groups). Questions: are balanced designs the best?, what if the cost of data is different for each group? -->

# %% [raw]
# <!-- 3. Proportion of variability among group of subjects \\ -->

# %% [raw]
# <!--     ($\sigma_{i} = \sigma_{g}$ where $g = 1, \dots, G$ groups), e.g., assuming two balanced groups ($N_{A} = N_{B}$) with $\sigma_{A[i]}^2 = p^{2}$ and $\sigma_{B[i]}^2 = 1-p^{2}$, where $0 \leq p \leq 1$, then the variance for a t-test among groups would be: $s_{p} = 1/\sqrt{2}$ -->

# %% [raw]
# <!-- For **RQ2b** the factors of interest will be: -->

# %% [raw]
# <!-- 1. Size of the effect ($\beta_{X}$ or $\beta_{Y}$) -->

# %% [raw]
# <!-- 2. Total number of subjects ($N$) -->

# %% [raw]
# <!-- For **RQ3a** the factors of interest will be: -->

# %% [raw]
# <!-- 1. Size of the difference between group of judges ($\beta_{Z}$) -->

# %% [raw]
# <!-- 2. Number of judges per group  -->

# %% [raw]
# <!--     ($K_{g}$ where $g=1,\dots,G$ groups). Questions: are balanced designs the best?, what if the cost of data is different for each group? -->

# %% [raw]
# <!-- 3. Proportion of variability among group of judges -->

# %% [raw]
# <!--     ($\sigma_{k} = \sigma_{g}$ where $g = 1, \dots, G$ groups), e.g., assuming two balanced groups ($K_{A} = K_{B}$) with $\sigma_{A[i]}^2 = p^{2}$ and $\sigma_{B[i]}^2 = 1-p^{2}$, where $0 \leq p \leq 1$, then the variance for a t-test among groups would be: $s_{p} = 1/\sqrt{2}$ -->

# %% [raw]
# <!-- For **RQ3b** the factors of interest will be: -->

# %% [raw]
# <!-- 1. Size of the effect $\beta_{Z}$ -->

# %% [raw]
# <!-- 2. Total number of judges ($K$) -->

# %% [markdown]
# ### 2.2 A scientific model for the DCJ procedure

# %% [raw]
# <!-- commands for d-separation -->

# %% [raw]
# \newcommand{\dsep}[2]{#1 \perp\kern-5pt\perp #2}
# \newcommand{\ndsep}[2]{#1 \not\!\perp\!\!\!\perp #2}

# %% [markdown]
# A *scientific (causal) model* describe the causal assumptions and mechanisms underlying a system, and facilitate inferences about causal relationships from data ([Hitchcock 2023](#ref-Hitchcock_2023)).

# %% [raw]
# <!-- To aid in the translation and visualization of the assumption underlying the DCJ procedure, Directed Acyclic Graphs (DAG) and Structural Causal Models (SCM) [@Pearl_2009; @Pearl_et_al_2016; @Cinelli_et_al_2021] are employed. DAG are . While SCM are . DAG conventions for this proposal are that ppen circles imply unobservable or latent variables , and that close circles indicate observable variables -->

# %% [raw]
# <!-- In *Dichotomous* Comparative Judgment (DCJ), a judge assesses the relative manifestation of a trait within a pair of stimuli. This results in a dichotomous value indicating which stimulus appears to possess a higher degree of the trait [@Pollitt_2012a; @Pollitt_2012b]. Following multiple rounds of pairwise comparisons made by different judges, an outcome vector is produced. Typically, this vector is modeled using the Bradley-Terry-Luce model [BTL model, @Bradley_et_al_1952; @Luce_1959; @Pollitt_2012a]. The set of latent variables produced by the model can then be utilized, for example, to rank the stimuli from lowest to highest, or to assess the impact of certain characteristics of the stimuli on their position in the ranking. -->

# %% [raw]
# <!-- According to @Verhavert_et_al_2019 and @vanDaal_2020, several assessment factors interplay and contribute to the reliability of the DCJ method. These factors include the number of stimuli, the characteristics of the stimuli, their *proximity* in terms of the assessed trait, the number of comparison per stimulus, and the pairing algorithm used. Furthermore, since the method relies on judges' assessments, the number of judges, the characteristics of judges, their *discrimination* abilities, and the number of comparisons per judge also play pivotal roles. Additionally, in cases where the stimuli represent sub-units of higher levels units, then the number of units, the characteristics of the units, and their *proximity* in terms of the trait can also significantly influence the assessment outcome. -->

# %% [raw]
# <!-- The research of @Boonen_et_al_2020 offers a clear illustration of these factors and their interplay. In their study, the authors focused on assessing children's  *overall perceived speech quality*. They evaluated this trait using six utterances (sub-units), each originating from $21$ children (units). The utterances were derived from an imitation task, while the children were evenly distributed across three groups: those with cochlear implants, those with hearing aids, and normal hearing children. To establish pairwise comparisons for the $126$ stimuli, a random pairing algorithm was employed, with $20$ comparisons per stimulus. Lastly, a total of $60$ listeners (judges) evaluated $65$ pairs of stimuli. The judges were selected from three distinct groups, each possessing varying degrees of experience with the speech of hearing-impaired children: audiologists, primary school teachers and inexperienced listeners. Ultimately, the authors were interested in assessing if there were differences in the *overall perceived speech quality* between groups of subjects and judges. -->

# %% [raw]
# <!-- ![DAG for the DCJ procedure](images/DCJ_DAG.tex) -->

# %% [raw]
# <!-- where $X_{i}$ describes subjects' background variables ($i = 1, \dots, j, \dots, N$), $Z_{k}$ the judges' background variables ($k = 1, \dots, K$), $Y_{r}$ the objects' background variables ($r_{i} = 1, \dots, R_{i}$). Furthermore, $\theta_{i}$ denotes the trait of subject $i$, $\gamma_{k}$ the judges' *discrimination* ability, $\theta_{ir_{i}}$ the trait of object $r_{i}$ from subject $i$, $\delta_{kijr_{ij}}$ the judge $k$ perception of trait differences between objects $r_{i}$ and $r_{j}$, from subjects $i$ and $j$. Additionally, $e_{k}$, $e_{i}$, and $e_{r_{i}}$ are the judges, subjects and objects idiosyncratic deviations. Lastly, $O_{kijr_{ij}}$ describes the dichotomous *observed* outcome -->

# %% [raw]
# <!-- Following what it is stated by the DAG, we can transform it into an SCM, in the following way -->

# %% [raw]
# <!-- $$ -->

# %% [raw]
# <!-- \begin{aligned}[t] -->

# %% [raw]
# <!--   O_{kijr_{ij}} := & \; f_{O}( \delta_{kijr_{ij}} ) \\ -->

# %% [raw]
# <!--   \delta_{kijr_{ij}} := & \; f_{D}( \gamma_{k}, \theta_{ir_{i}} ) \\ -->

# %% [raw]
# <!--   \gamma_{k} := & \; f_{G}( Z_{k}, e_{k} ) \\ -->

# %% [raw]
# <!--   \theta_{ir_{i}} := & \; f_{R}( \theta_{i}, Y_{r}, e_{r_{i}} ) \\ -->

# %% [raw]
# <!--   \theta_{i} := & \; f_{T}( X_{i}, e_{i} ) \\ -->

# %% [raw]
# <!--   & \; \dsep{e_{k}}{e_{i}} \\ -->

# %% [raw]
# <!--   & \; \dsep{e_{k}}{e_{r_{i}}} \\ -->

# %% [raw]
# <!--   & \; \dsep{e_{i}}{e_{r_{i}}} -->

# %% [raw]
# <!-- \end{aligned} -->

# %% [raw]
# <!-- $$ {#eq-StructuralModel} -->

# %% [markdown]
# ### 2.3 From the scientific to the statistical DCJ model

# %% [raw]
# <!-- "An appropriate analysis of data cannot be completed without knowledge of what experimental design was used and how the data was collected, and conclusions are not reliable if they are not justified by the proper modeling and analysis of the data" [see @Lawson_2015, pp. 7] -->

# %% [raw]
# <!-- It is more likely that we can decide the characteristics of the objects we want to include in the study (independent variables), ensuring groups that are more balanced. However, in the case of subjects sometimes the independent variables cannot be assigned (e.g., hearing status). -->

# %% [raw]
# <!-- "In many cases where observational units are different than the experimental units, the observational units will not be independent" [see @Lawson_2015, pp. 177] -->

# %% [raw]
# <!-- 3. Considering the predictability of the phenomena -->

# %% [raw]
# <!--       its importance in @Shmueli_et_al_2011 and Lawson [-@Lawson_2015, pp. 7] -->

# %% [raw]
# <!-- Bayesian Bradley-Terry-Luce model (BTL) [@Bradley_et_al_1952, @Luce_1959, @Pollitt_2012b, @BradleyTerry2_2012]  -->

# %% [raw]
# <!-- $$ -->

# %% [raw]
# <!-- \begin{aligned}[t] -->

# %% [raw]
# <!--   O_{kijr_{ij}} \sim & \; \text{Bernoulli}\left[ \; \text{inv}\_\text{logit}\left( \delta_{kijr_{ij}} \right) \; \right] \\ -->

# %% [raw]
# <!--   \delta_{kijr_{ij}} = & \; \gamma_{k}( \theta_{ir_{i}} - \theta_{jr_{j}} ) \\ -->

# %% [raw]
# <!--   \gamma_{k} \sim & \; \text{Log-Normal}( \beta_{Z} Z_{k},\; \sigma_{k} ) \\ -->

# %% [raw]
# <!--   \theta_{ir_{i}} \sim & \; \text{Normal}( \theta_{i} + \beta_{Y} Y_{r},\; \sigma_{r_{i}} )  \\ -->

# %% [raw]
# <!--   \theta_{i} \sim & \; \text{Normal}( \beta_{X} X_{i},\; \sigma_{i}) \\ -->

# %% [raw]
# <!--   \sigma_{k} = & \; 1/10 \\ -->

# %% [raw]
# <!--   \sigma_{i} = & \; 1 \\ -->

# %% [raw]
# <!--   \sigma_{r_{i}} \sim & \; \text{Exponential}(2) -->

# %% [raw]
# <!-- \end{aligned} -->

# %% [raw]
# <!-- $$ {#eq-StatisticalModel1} -->

# %% [raw]
# <!-- $$ -->

# %% [raw]
# <!-- \begin{aligned}[t] -->

# %% [raw]
# <!--   O_{kijr_{ij}} \sim & \; \text{Bernoulli}\left[ \; \text{inv}\_\text{logit}\left( \delta_{kijr_{ij}} \right) \; \right] \\ -->

# %% [raw]
# <!--   \delta_{kijr_{ij}} = & \; \gamma_{k}( \theta_{ir_{i}} - \theta_{jr_{j}} ) \\ -->

# %% [raw]
# <!--   \gamma_{k} = & \; exp\left(\beta_{Z} Z_{k} + e_{k} \right) \\ -->

# %% [raw]
# <!--   \theta_{ir_{i}} = & \; \theta_{i} + \beta_{Y} Y_{r} + e_{r_{i}}  \\ -->

# %% [raw]
# <!--   \theta_{i} = & \; \beta_{X} X_{i} + e_{i}  \\ -->

# %% [raw]
# <!--   e_{k} \sim & \; \text{Normal}(0, 1/10) \\ -->

# %% [raw]
# <!--   e_{i} \sim & \; \text{Normal}(0, 1) \\ -->

# %% [raw]
# <!--   e_{r_{i}} \sim & \; \text{Normal}(0, \sigma_{r_{i}}) \\ -->

# %% [raw]
# <!--   \sigma_{r_{i}} \sim & \; \text{Exponential}(2) -->

# %% [raw]
# <!-- \end{aligned} -->

# %% [raw]
# <!-- $$ {#eq-StatisticalModel2} -->

# %% [markdown]
# ## 3 Methods
#
# ### 3.1 Bayesian simulation and power analysis

# %% [raw]
# <!-- "Power analysis is only useful when the simulated data imitate actual data ... We assume that the model is a reasonably good description of the actual data" [see @Kruschke_2015, pp. 394] -->

# %% [raw]
# <!-- In terms of the highest density interval (HDI), power can be expressed in three goals [@Kruschke_2015]: -->

# %% [raw]
# <!-- 1. **Reject a null value of a parameter** -->

# %% [raw]
# <!--     *Formal expression:* Show that a region of practical equivalence (ROPE) around the null value excludes the posterior $95\%$ HDI. -->

# %% [raw]
# <!-- 2. **Affirm a predicted value of a parameter** -->

# %% [raw]
# <!--     *Formal expression:* Show that a ROPE around the predicted value includes the posterior $95\%$ HDI. -->

# %% [raw]
# <!-- 3. **Achieve precision in the estimate of a parameter** -->

# %% [raw]
# <!--     *Formal expression:* Show that the posterior $95\%$ HDI has width less than a specified maximum. -->

# %% [raw]
# <!-- According to the definition of @Lawson_2015 -->

# %% [raw]
# <!-- In the context of DCJ -->

# %% [raw]
# <!-- Experiment:  -->

# %% [raw]
# <!-- present two objects coming from two subjects to a judge, who will assess which object among the two have a greater amount of the trait under assessment. If object A have more of the trait than B, then you score it with a 1, otherwise 0 -->

# %% [raw]
# <!-- Ideal scenario: -->

# %% [raw]
# <!-- all judges assess all pairs of subjects, with all pairs of objects, more than one time [see @Lawson_2015, pp. 262] (recipe example) -->

# %% [raw]
# <!-- Experimental unit:  -->

# %% [raw]
# <!-- Trials of the experiment, where a pair of subjects is rated by a judge using two pairs of objects [see @Lawson_2015, pp. 124] (GCB) -->

# %% [raw]
# <!-- Observational unit:  -->

# %% [raw]
# <!-- objects within subjects (they work as items in IRT?) -->

# %% [raw]
# <!-- Treatment variable:  -->

# %% [raw]
# <!-- Two subjects under comparison -->

# %% [raw]
# <!-- Independent variable: -->

# %% [raw]
# <!-- characteristics of the subjects or objects -->

# %% [raw]
# <!-- Background variable:  -->

# %% [raw]
# <!-- Unknown, it is subject-matter specific -->

# %% [raw]
# <!-- Blocking variable:  -->

# %% [raw]
# <!-- a. Judges? (In BIB) -->

# %% [raw]
# <!-- b. Block of day in which the experiment is performed -->

# %% [raw]
# <!-- Dependent variable (response):  -->

# %% [raw]
# <!-- dichotomous rating -->

# %% [raw]
# <!-- Effect:  -->

# %% [raw]
# <!-- 1. differences among individuals -->

# %% [raw]
# <!-- 2. changes in response by changing treatment factors -->

# %% [raw]
# <!-- 3. Changes in response by changing blocking variable -->

# %% [raw]
# <!-- Replicate runs:  -->

# %% [raw]
# <!-- experiments where either one or two of the subjects in the pair is different. Best case scenario is when all pairs of subjects are compaired with all pairs of objects at least by one judge (one block) -->

# %% [raw]
# <!-- Duplicate runs:  -->

# %% [raw]
# <!-- experiments where the same judge compares the same two subjects more than one time. Best case scenario is when all judges assess the same pair of subjects more than one time (with different or the same objects) -->

# %% [raw]
# <!-- e.g., If the measured response changes with the objects, then the response is varying due to measurement error, and therefore, objects constitute duplicate runs.  -->

# %% [raw]
# <!-- If the same judge assess the same two objects from the same two subjects more than one time, then the variability of the assessment of the judge can be partitioned additionally into variance between pairs of objects and variance within pairs of objects. -->

# %% [raw]
# <!-- From @Lawson_2015, another way to see DCJ experiments I'd that you are grouping heterogeneous experimental units (objects and subjects) into homogeneous ones (judges), which are your "blocks". In that case if you expect that blocking will reduce the variance of EUs within blocks by a percentage equal to $100*\left(1-\frac{1}{RE}\right)$ where $RE$ is the relative efficiency in respect to a CRD  then the replicates would be $r=r_{crd}/RE$ and the number of blocks of size $k$ would be $b=tr/k$ [see @Lawson_2015, pp. 121-122, pp. 267] -->

# %% [raw]
# <!-- Usually, in these types of experiments the objects are observational units from higher hierarchical levels, such as subjects. For example, when researchers are interested in assessing the trait of speech intelligibility of individuals (subjects), judges rate dichotomously two uttered sentences (objects, nested within individuals). -->

# %% [raw]
# <!-- Generate random data up until judges and subjects abilities. Then for the population assume you made all comparisons. Then sample with BIB [@Lawson_2015] the pairs compared. -->

# %% [raw]
# <!-- For effect size test, simulate individuals from the distribution, identify which have a desired difference and calculate power on those individuals. -->

# %% [raw]
# <!-- Track the total number of comparison per subjects as another representation -->

# %% [raw]
# <!-- Steps: -->

# %% [raw]
# <!-- 1. Define parameters generating the population, by factorial design -->

# %% [raw]
# <!-- 2. Generate a population: 500 subjects, 100 objects and all comparisons made 100 times -->

# %% [raw]
# <!-- 3. Sample from population with BIB -->

# %% [raw]
# <!-- 4. Run model on the sample -->

# %% [raw]
# <!-- 5. Report the goals -->

# %% [raw]
# <!-- 6. Repeat steps 3-5 for a specific number of simulations. -->

# %% [raw]
# <!-- 7. Repeat steps 1-6 for all parameters combinations -->

# %% [markdown]
# ## 4 Results
#
# ### 4.1 Research question 1
#
# ### 4.2 Research question 2
#
# ### 4.3 Research question 3
#
# ## 5 Discussion

# %% [raw]
# <!-- When you want to investigate objects, the experiment has an experimental unit: the trial on the objects, but you only have one object per subject. Consequently, objects and subjects are confounded. -->

# %% [markdown]
# ### 5.1 Limitations and further research

# %% [raw]
# <!-- We are trying to do prospective power analysis, however, you should pose the possibility that other authors perform replication power [see @Kruschke_2015, pp. 393]. The next paper is going to perform retrospective power analysis -->

# %% [raw]
# <!-- The study only compared the reliability coefficients between the adaptive and non-adaptive studies, without considering other aspects of validity or the impact on external variables -->

# %% [raw]
# <!-- Prospect of future research: -->

# %% [raw]
# <!-- - Does the pairing algorithm have an impact on any of the three research questions? -->

# %% [raw]
# <!-- - What is the maximum of comparisons per judge to avoid loosing discrimination ability?, is it task-specific? (most likely) -->

# %% [markdown]
# ## 6 Conclusion
#
# ## References
#
# Agresti, A. 1992. “Analysis of Ordinal Paired Comparison Data.” *Journal of the Royal Statistical Society* 41 (2): 287–97. <https://doi.org/10.2307/2347562>.
#
# Bartholomew, S., L. Nadelson, W. Goodridge, and E. Reeve. 2018. “Adaptive Comparative Judgment as a Tool for Assessing Open-Ended Design Problems and Model Eliciting Activities.” *Educational Assessment* 23 (2): 85–101. <https://doi.org/10.1080/10627197.2018.1444986>.
#
# Bartholomew, S., and P. Williams. 2020. “STEM Skill Assessment: An Application of Adaptive Comparative Judgment.” In *Integrated Approaches to STEM Education. Advances in STEM Education*, edited by J. Anderson and Y. Li. Springer. <https://doi.org/10.1007/978-3-030-52229-2_18>.
#
# Boonen, N., H. Kloots, and S. Gillis. 2020. “Rating the Overall Speech Quality of Hearing-Impaired Children by Means of Comparative Judgements.” *Journal of Communication Disorders* 83: 1675–87. <https://doi.org/10.1016/j.jcomdis.2019.105969>.
#
# Bradley, R., and M. Terry. 1952. “Rank Analysis of Incomplete Block Designs: I. The Method of Paired Comparisons.” *Biometrika* 39 (3-4): 324–45. <https://doi.org/10.2307/2334029>.
#
# Bramley, T. 2015. “Investigating the Reliability of Adaptive Comparative Judgment.” <http://www.cambridgeassessment.org.uk/Images/232694-investigating-the-reliability-of-adaptive-comparative-judgment.pdf>.
#
# Bramley, T., and S. Vitello. 2019. “The Effect of Adaptivity on the Reliability Coefficient in Adaptive Comparative Judgement.” *Assessment in Education: Principles, Policy and Practice* 71 (9): 1–25. <https://doi.org/10.1080/0969594X.2017.1418734>.
#
# Cinelli, C., A. Forney, and J. Pearl. 2022. “A Crash Course in Good and Bad Controls.” *SSRN*, September. https://doi.org/<http://dx.doi.org/10.2139/ssrn.3689437>.
#
# Crompvoets, Elise A. V., Anton A. Béguin, and Klaas Sijtsma. 2022. “On the Bias and Stability of the Results of Comparative Judgment.” *Frontiers in Education* 6. <https://doi.org/10.3389/feduc.2021.788202>.
#
# Gijsen, M., T. van Daal, Marije Lesterhuis, David Gijbels, and Sven de Maeyer. 2021. “The Complexity of Comparative Judgments in Assessing Argumentative Writing: An Eye Tracking Study.” *Frontiers in Education* 5. <https://doi.org/10.3389/feduc.2020.582800>.
#
# Hitchcock, C. 2023. “Causal Models.” In *The Stanford Encyclopedia of Philosophy*, edited by Edward N. Zalta and Uri Nodelman, Spring 2023. Metaphysics Research Lab, Stanford University. <https://plato.stanford.edu/archives/spr2023/entries/causal-models/>.
#
# Lesterhuis, M. 2018. “The Validity of Comparative Judgement for Assessing Text Quality: An Assessor’s Perspective.” PhD thesis, University of Antwerp.
#
# Luce, R. 1959. “On the Possible Psychophysical Laws.” *The Psychologcal Review* 66 (2): 482–99. <https://doi.org/10.1037/h0043178>.
#
# Marshall, N., K Shaw, J. Hunter, and I. Jones. 2020. “Assessment by Comparative Judgement: An Application to Secondary Statistics and English in New Zealand.” *New Zealand Journal of Educational Studies* 55: 49–71. <https://doi.org/10.1007/s40841-020-00163-3>.
#
# McElreath, R. 2020. *[Statistical Rethinking: A Bayesian Course with Examples in r and STAN]()*. Chapman; Hall/CRC.
#
# Neal, B. 2020. “Introduction to Causal Inference from a Machine Learning Perspective.” [\url{https://www.bradyneal.com/Introduction_to_Causal_Inference-Dec17_2020-Neal.pdf}](\url{https://www.bradyneal.com/Introduction_to_Causal_Inference-Dec17_2020-Neal.pdf}).
#
# Pearl, J. 2009. *[Causality: Models, Reasoning and Inference]()*. Cambrige University Press.
#
# Pearl, J., M. Glymour, and N. Jewell. 2016. *[Causal Inference in Statistics: A Primer]()*. John Wiley & Sons, Inc.
#
# Plackett, R. 1975. “The Analysis of Permutations.” *Journal of the Royal Statistical Society* 24 (2): 193–202. <https://doi.org/10.2307/2346567>.
#
# Pollitt, A. 2012a. “Comparative Judgement for Assessment.” *International Journal of Technology and Design Education* 22 (2): 157--170. <https://doi.org/10.1007/s10798-011-9189-x>.
#
# ———. 2012b. “The Method of Adaptive Comparative Judgement.” *Assessment in Education: Principles, Policy and Practice* 19 (3): 281--300. <https://doi.org/10.1080/0969594X.2012.665354>.
#
# Thurstone, L. 1927. “A Law of Comparative Judgment.” *Psychological Review* 34 (4): 482–99. <https://doi.org/10.1037/h0070288>.
#
# Tutz, G. 1986. “Bradley-Terry-Luce Model with an Ordered Response.” *Journal of Mathemathical Psychology* 30 (3): 306–16. <https://doi.org/10.1016/0022-2496(86)90034-9>.
#
# van Daal, T. 2020. “Making a Choice Is Not Easy?!: Unravelling the Task Difficulty of Comparative Judgement to Assess Student Work.” PhD thesis, University of Antwerp.
#
# van Daal, T., M. Lesterhuis, L. Coertjens, V. Donche, and S. De Maeyer. 2019. “Validity of Comparative Judgement to Assess Academic Writing: Examining Implications of Its Holistic Character and Building on a Shared Consensus.” *Assessment in Education: Principles, Policy & Practice* 26 (1): 59–74. <https://doi.org/10.1080/0969594X.2016.1253542>.
#
# van Daal, T., M. Lesterhuis, L. Coertjens, MT. van de Kamp, V. Donche, and Sven de Maeyer. 2017. “The Complexity of Assessing Student Work Using Comparative Judgment: The Moderating Role of Decision Accuracy.” *Frontiers in Education* 2. <https://doi.org/10.3389/feduc.2017.00044>.
#
# Verhavert, S., R. Bouwer, V Donche, and S. De Maeyer. 2019. “A Meta-Analysis on the Reliability of Comparative Judgement.” *Assessment in Education: Principles, Policy and Practice* 26 (5): 541–62. <https://doi.org/10.1080/0969594X.2019.1602027>.

# %% [raw]
# <!-- -->

# %% [markdown]
# ```` markdown
# ---
# title: The interplay of assessment factors in Dichotomous Comparative Judgments
# subtitle: A Bayesian simulation-based power analysis exploring their impacts on the method's reliability
# author:
#   - name:
#       given: Jose Manuel
#       family: Rivera Espejo
#     orcid: 0000-0002-3088-2783
#     url: https://www.uantwerpen.be/en/staff/jose-manuel-rivera-espejo_23166/
#     email: JoseManuel.RiveraEspejo@uantwerpen.be
#     corresponding: true
#     roles: [conceptualization, data curation, analysis, investigation, methodology, software, validation, visualization, writing]
#     affiliation:
#       - name: University of Antwerp
#         department: Education sciences
#         group: Edubron
#   - name:
#       given: Sven
#       family: Maeyer
#       non-dropping-particle: de
#     orcid: 0000-0003-2888-1631
#     url: https://www.uantwerpen.be/en/staff/sven-demaeyer/
#     email: sven.demaeyer@uantwerpen.be
#     corresponding: false
#     roles: [conceptualization, funding, investigation, methodology, project administration, resources, supervision, validation, editing]
#     affiliation:
#       - name: University of Antwerp
#         department: Education sciences
#         group: Edubron
#   - name:
#       given: Steven
#       family: Gillis
#     orcid:
#     url: https://www.uantwerpen.be/nl/personeel/steven-gillis/
#     email: steven.gillis@uantwerpen.be
#     corresponding: false
#     roles: [conceptualization, funding, investigation, methodology, project administration, resources, supervision, editing]
#     affiliation:
#       - name: University of Antwerp
#         department: Linguistics
#         group: Centre for computational linguistics, psycholinguistics, and sociolinguistics (CLiPS)
# funding:
#   statement: "The project was founded through the Research Fund of the University of Antwerp (BOF)."
# keywords:
#   - power analysis
#   - comparative judgment
#   - bayesian analysis
#   - simulation
# abstract: |
#   (to do) ...
# plain-languquarto installage-summary: |
#   (to do) ...
# key-points:
#   - (to do)
# date: last-modified
# bibliography: references.bib
# citation: true
#   # type: article-journal
#   # container-title: ""
#   # publisher: ""
#   # issued: 2020/09/23
#   # issue:
#   # volume: 2
#   # doi: ""
#   # url: https://example.com/summarizing-output
#   # page-first: 46
#   # page-last: 53
#   # editor:
#   # - Don Draper
#   # - Nick Fury
# ---
#
# ## Introduction {#sec-introduction}
#
# <!-- [(citation needed)]{style="color:red;"} -->
#
# <!-- 1. What is comparative judgment? -->
# In contemporary contexts, Thurstone's law of comparative judgment [-@Thurstone_1927] primarily refers to the method of *Dichotomous* Comparative Judgment (DCJ). Within DCJ, a judge assesses the relative manifestation of a trait within a pair of stimuli. This results in a dichotomous value indicating which stimulus appears to possess a higher degree of the trait [@Pollitt_2012a; @Pollitt_2012b]. Following multiple rounds of pairwise comparisons made by different judges, an outcome vector is produced. Typically, this vector is modeled using the Bradley-Terry-Luce model [BTL model, @Bradley_et_al_1952; @Luce_1959; @Pollitt_2012a]. The set of latent variables produced by the model can then be utilized, for example, to rank the stimuli from lowest to highest, or to assess the impact of certain characteristics of the stimuli on their position in the ranking.
#
# <!-- 2. in what has been applied on?, and where is the gap? -->
# DCJ has proven effective in assessing competences and traits predominantly within the educational realm, as demonstrated by the works of @Pollitt_2012b, @Bartholomew_et_al_2018, @vanDaal_et_al_2016 @Lesterhuis_2018, and @Bartholomew_et_al_2020. However, its application transcends education, as exemplified by the work of @Boonen_et_al_2020. The methodology has also evolved to include multiple, as opposed to pairwise comparisons [@Luce_1959; @Placket_1975] and to accommodate comparisons with ordinal outcomes [@Tutz_1986; @Agresti_1992]. Overall, research suggests that DCJ offers an alternative and efficient approach to measurement and evaluation, characterized by its reliability and validity [@Lesterhuis_2018; @vanDaal_2020; @Marshall_et_al_2020]. Nevertheless, considering the method's sophistication, there has been limited investigation about the interplay of the different assessment factors and their contribution to the method's reliability.
#
# <!-- 3. What are the factors behind DCJ? -->
# According to @Verhavert_et_al_2019 and @vanDaal_2020, several assessment factors interplay and contribute to the reliability of the DCJ method. These factors include the number of stimuli, the characteristics of the stimuli, their *proximity* in terms of the assessed trait, the number of comparison per stimulus, and the pairing algorithm used. Furthermore, since the method relies on judges' assessments, the number of judges, the characteristics of judges, their *discrimination* abilities, and the number of comparisons per judge also play pivotal roles. Additionally, in cases where the stimuli represent sub-units (e.g., objects) from higher-levels units (e.g., subjects), then the number of units, the characteristics of the units, and their *proximity* in terms of the trait can also significantly influence the assessment outcome.
#
# The research of @Boonen_et_al_2020 offers a clear illustration of these factors and their interplay in a DCJ procedure. In their study, the authors evaluated the *overall perceived speech quality* (i.e., the trait) using six utterances (objects), each originating from $21$ children (subjects). The utterances were derived from an imitation task, while the children were evenly distributed across three groups: those with cochlear implants, those with hearing aids, and normal hearing children. To establish pairwise comparisons for the $126$ stimuli, a random pairing algorithm was employed, with $20$ comparisons per stimulus. Lastly, a total of $60$ listeners (judges) evaluated $65$ pairs of stimuli. The judges were equally selected from three distinct groups, each possessing varying degrees of experience with the speech of hearing-impaired children: audiologists, primary school teachers and inexperienced listeners. Ultimately, the authors were interested in assessing if there were differences in the *overall perceived speech quality* between groups of subjects and judges.
#
# <!-- 4. Where is the gap? -->
# Previous studies have primarily focused on examining the individual impact of the different assessment factors on the reliability of DCJ. For instance, @Bramley_2015 conducted a simulation-based study to investigate the effects of using random versus adaptive pairing algorithms on the Scale Separation Reliability [SSR, @Pollitt_2012b]. In a similar vein, @Bramley_et_al_2019 explored the influence of adaptive algorithms on the SSR using autobiographical essays from candidates in an English Language course, where the essays constituted half of the total marks for the final exam. In contrast, @Verhavert_et_al_2019 conducted a meta-analysis examining the individual effects of various assessment factors on the SSR, including the number of stimuli, the format of stimuli, the number of comparisons per stimulus, the number of judges, the judges' expertise, and feedback. @Crompvoets_et_al_2022 then examined through a simulation study how variations in the number of comparisons per stimulus affect the bias and stability of SSR components. Additionally, @vanDaal_et_al_2017 and @Gijsen_et_al_2021 explored the moderating role of judges' decision accuracy on the perceived complexity when comparing two stimuli. However, to the best of the author's knowledge, there has been no systematic investigation into how different relevant assessment factors interact and what is their collective effect on the reliability of the DCJ method.
#
# <!-- 5. Solution to the gap -->
# This study aims to address this gap by conducting a Bayesian simulation-based power analysis, following the Identification-Estimation flowchart outlined by McElreath [-@McElreath_2020] and Neal [-@Neal_2020]. First, it defines the different targets of inference (i.e., the *estimands*), which are articulated through three research questions, over which the reliability of the DCJ method is evaluated. Subsequently, a *scientific model* for the DCJ procedure is constructed. These models describe the causal assumptions and mechanisms underlying the system, and facilitate inferences about causal relationships from data [@Hitchcock_2023]. To aid in the translation and visualization of the assumption underlying the DCJ procedure, Directed Acyclic Graphs (DAG) and Structural Causal Models (SCM) [@Pearl_2009; @Pearl_et_al_2016; @Cinelli_et_al_2021] are employed. Next, an *estimator* in the form of a statistical model is utilized to derive an *statistical estimand* for the various targets of inference. Bayesian statistical method offer an intuitive approach to translate scientific models into probabilistic estimators. Finally, employing multiple simulated datasets for different combinations of the relevant assessment factors, the study generates multiple *estimates* for the statistical estimands. Notably, the statistical estimands in simulated data are known, consequently, the study can assess the DCJ reliability by evaluating the *proximity* to these estimands to the generated estimates. This final step resembles a power analysis. Ultimately, the outcomes of this study will inform the planning of DCJ experiments and hold significance for researchers or analysts involved in education and assessment procedures who implement DCJ methodologies.
#
#
# ## Theoretical framework {#sec-TheoreticalFramework}
#
# In order to evaluate the reliability of the DCJ method, first the study need to define certain terminology. This study uses the Identification-Estimation flowchart [@McElreath_2020; @Neal_2020]. The flowchart illustrates the process of moving from a target (causal) *estimand* to a corresponding *estimate*, through identification and estimation (@fig-IEflowchart). An *estimand* is the target of inference of the quantity that we want to estimate. An *estimate* is an approximation of the *estimand*, which is obtained by using data. Moreover, identification refers to the process of moving from a (causal) *estimand* to an equivalent *statistical estimand*, and estimation refers to the process of moving from a *statistical estimand* to an *estimate*.
#
# quarto-executable-code-5450563D
#
# ```dot
# //| echo: false
# //| warning: false
# //| error: false
# //| label: fig-IEflowchart
# //| fig-cap: "Identification-Estimation flowchart. Extracted from @Neal_2020"
# //| fig-height: 4
# //| fig-width: 4
# digraph IE {
#     layout=neato
#
#     A [shape=box, label="(Causal) Estimand", pos="0,1!"]
#     B [shape=box, label="Scientific model", pos="2,1!"]
#     C [shape=box, label="Statistical Estimand", pos="0,0!"]
#     D [shape=box, label="Data", pos="2,0!"]
#     E [shape=box, label="Estimate", pos="0,-1!"]
#     F [shape=plaintext, label="Identification", pos="0.2,0.5"]
#     G [shape=plaintext, label="Estimation", pos="0.2,1"]
#
#     A -> C
#     B -> C
#     C -> E
#     D -> E
#
# }
# ```
#
# <!-- ![Identification-Estimation workflow](images/DCJ_DAG.tex) -->
#
# ### Research questions and their estimands {#sec-ResearchQuestions}
#
# <!-- **Research question 1** is interested in *which factors have an impact on the power to make comparisons between subjects' traits, with $95\%$ ($1-\alpha$) confidence?* (RQ1), when we want to compare: two random subjects, or one random subject versus a reference subject. Consequently the parameter of interest is $\theta_{i} - \theta_{j}$. -->
#
# <!-- Considering the results of **RQ1**, **Research question 2a** is interested in *which factors have an impact on the power to make comparisons of the average trait between groups of subjects / objects, with $95\%$ ($1-\alpha$) confidence?* (RQ2a). Consequently, the parameters of interest will be the $\beta_{X}$ or $\beta_{Y}$, if $X$ or $Y$ define two or more groups (or interactions). -->
#
#
# <!-- Considering the results of **RQ1**, **Research question 2b** is interested in *which factors have an impact on the power of covariates' regression parameters on the trait of subjects / objects, with $95\%$ ($1-\alpha$) confidence?* (RQ2b). Consequently, the parameters of interest will be the $\beta_{X}$ or $\beta_{Y}$, if $X$ or $Y$ define a continuous covariate. -->
#
#
# <!-- Considering the results of **RQ1**, **Research question 3a** is interested in *which factors have an impact on the power to make comparisons of the average "discrimination" ability between groups of judges, with $95\%$ ($1-\alpha$) confidence?}* (RQ3a). Consequently, the parameters of interest will be the $\beta_{Z}$ or $\beta_{Y}$, if $Z$ define two or more groups (or interactions). -->
#
# <!-- Considering the results of **RQ1**, **Research question 3b** is interested in *which factors have an impact on the power of covariates' regression parameters from covariates on the judgment ability of judges, with $95\%$ ($1-\alpha$) confidence?* (RQ3b). Consequently, the parameters of interest will be the $\beta_{Z}$, if $Z$ define a continuous covariate. -->
#
# <!-- For **RQ1** the factors of interest will be: -->
#
# <!-- 1. Number of objects per subject ($R_{i}$) -->
# <!-- 2. Number of comparisons per object -->
# <!-- 3. Variability of objects within each subject ($\sigma_{r_{i}}$) -->
# <!-- 4. Number of judges ($K$) -->
#
# <!--     indirectly determined by the number of comparison per judge, see \cite{Lawson_2015}, p. 263-264) -->
#
# <!-- 5. Judges' "discrimination" ability ($\gamma_{k}$) -->
# <!-- 6. Trait difference size between subjects ($\theta_{i} - \theta_{j}$) -->
#
#
# <!-- **RQ1** will not investigate the following factors: -->
#
# <!-- 1. Pairing algorithm (see \cite{Bramley_2015}). -->
#
# <!--       We will use a random algorithm (Balanced Incomplete Block design, BIB \cite{Lawson_2015})  -->
#
# <!-- 2. Number of comparisons per judge,  -->
#
# <!--       we assign the maximum number of comparison physically possible per judge, i.e., a fixed value (although, this is task specific)  -->
#
# <!-- 3. Format of the assessed object (see \cite{Verhavert_2018})  -->
#
# <!--     It is indirectly investigated in \textit{RQ2a} and \textit{RQ2b} -->
#
# <!-- 4. The variability proportion among group of subjects  -->
#
# <!--     It is indirectly investigated in \textit{RQ2a} and \textit{RQ2b}  -->
#
#
# <!-- For **RQ2a** the factors of interest will be: -->
#
# <!-- 1. Trait difference size between group of subjects / objects ($\beta_{X}$ or $\beta_{Y}$) -->
# <!-- 2. Number of subjects per group -->
#
# <!--     ($N_{g}$ where $g = 1, \dots, G$ groups). Questions: are balanced designs the best?, what if the cost of data is different for each group? -->
#
# <!-- 3. Proportion of variability among group of subjects \\ -->
#
# <!--     ($\sigma_{i} = \sigma_{g}$ where $g = 1, \dots, G$ groups), e.g., assuming two balanced groups ($N_{A} = N_{B}$) with $\sigma_{A[i]}^2 = p^{2}$ and $\sigma_{B[i]}^2 = 1-p^{2}$, where $0 \leq p \leq 1$, then the variance for a t-test among groups would be: $s_{p} = 1/\sqrt{2}$ -->
#
#
# <!-- For **RQ2b** the factors of interest will be: -->
#
# <!-- 1. Size of the effect ($\beta_{X}$ or $\beta_{Y}$) -->
# <!-- 2. Total number of subjects ($N$) -->
#
#
# <!-- For **RQ3a** the factors of interest will be: -->
#
# <!-- 1. Size of the difference between group of judges ($\beta_{Z}$) -->
# <!-- 2. Number of judges per group  -->
#
# <!--     ($K_{g}$ where $g=1,\dots,G$ groups). Questions: are balanced designs the best?, what if the cost of data is different for each group? -->
#
# <!-- 3. Proportion of variability among group of judges -->
#
# <!--     ($\sigma_{k} = \sigma_{g}$ where $g = 1, \dots, G$ groups), e.g., assuming two balanced groups ($K_{A} = K_{B}$) with $\sigma_{A[i]}^2 = p^{2}$ and $\sigma_{B[i]}^2 = 1-p^{2}$, where $0 \leq p \leq 1$, then the variance for a t-test among groups would be: $s_{p} = 1/\sqrt{2}$ -->
#
#
# <!-- For **RQ3b** the factors of interest will be: -->
#
# <!-- 1. Size of the effect $\beta_{Z}$ -->
# <!-- 2. Total number of judges ($K$) -->
#
#
# ### A scientific model for the DCJ procedure {#sec-SciMod}
#
# <!-- commands for d-separation -->
# \newcommand{\dsep}[2]{#1 \perp\kern-5pt\perp #2}
# \newcommand{\ndsep}[2]{#1 \not\!\perp\!\!\!\perp #2}
#
# A *scientific (causal) model* describe the causal assumptions and mechanisms underlying a system, and facilitate inferences about causal relationships from data [@Hitchcock_2023].
#
# <!-- To aid in the translation and visualization of the assumption underlying the DCJ procedure, Directed Acyclic Graphs (DAG) and Structural Causal Models (SCM) [@Pearl_2009; @Pearl_et_al_2016; @Cinelli_et_al_2021] are employed. DAG are . While SCM are . DAG conventions for this proposal are that ppen circles imply unobservable or latent variables , and that close circles indicate observable variables -->
#
# <!-- In *Dichotomous* Comparative Judgment (DCJ), a judge assesses the relative manifestation of a trait within a pair of stimuli. This results in a dichotomous value indicating which stimulus appears to possess a higher degree of the trait [@Pollitt_2012a; @Pollitt_2012b]. Following multiple rounds of pairwise comparisons made by different judges, an outcome vector is produced. Typically, this vector is modeled using the Bradley-Terry-Luce model [BTL model, @Bradley_et_al_1952; @Luce_1959; @Pollitt_2012a]. The set of latent variables produced by the model can then be utilized, for example, to rank the stimuli from lowest to highest, or to assess the impact of certain characteristics of the stimuli on their position in the ranking. -->
#
# <!-- According to @Verhavert_et_al_2019 and @vanDaal_2020, several assessment factors interplay and contribute to the reliability of the DCJ method. These factors include the number of stimuli, the characteristics of the stimuli, their *proximity* in terms of the assessed trait, the number of comparison per stimulus, and the pairing algorithm used. Furthermore, since the method relies on judges' assessments, the number of judges, the characteristics of judges, their *discrimination* abilities, and the number of comparisons per judge also play pivotal roles. Additionally, in cases where the stimuli represent sub-units of higher levels units, then the number of units, the characteristics of the units, and their *proximity* in terms of the trait can also significantly influence the assessment outcome. -->
#
# <!-- The research of @Boonen_et_al_2020 offers a clear illustration of these factors and their interplay. In their study, the authors focused on assessing children's  *overall perceived speech quality*. They evaluated this trait using six utterances (sub-units), each originating from $21$ children (units). The utterances were derived from an imitation task, while the children were evenly distributed across three groups: those with cochlear implants, those with hearing aids, and normal hearing children. To establish pairwise comparisons for the $126$ stimuli, a random pairing algorithm was employed, with $20$ comparisons per stimulus. Lastly, a total of $60$ listeners (judges) evaluated $65$ pairs of stimuli. The judges were selected from three distinct groups, each possessing varying degrees of experience with the speech of hearing-impaired children: audiologists, primary school teachers and inexperienced listeners. Ultimately, the authors were interested in assessing if there were differences in the *overall perceived speech quality* between groups of subjects and judges. -->
#
# <!-- ![DAG for the DCJ procedure](images/DCJ_DAG.tex) -->
#
# <!-- where $X_{i}$ describes subjects' background variables ($i = 1, \dots, j, \dots, N$), $Z_{k}$ the judges' background variables ($k = 1, \dots, K$), $Y_{r}$ the objects' background variables ($r_{i} = 1, \dots, R_{i}$). Furthermore, $\theta_{i}$ denotes the trait of subject $i$, $\gamma_{k}$ the judges' *discrimination* ability, $\theta_{ir_{i}}$ the trait of object $r_{i}$ from subject $i$, $\delta_{kijr_{ij}}$ the judge $k$ perception of trait differences between objects $r_{i}$ and $r_{j}$, from subjects $i$ and $j$. Additionally, $e_{k}$, $e_{i}$, and $e_{r_{i}}$ are the judges, subjects and objects idiosyncratic deviations. Lastly, $O_{kijr_{ij}}$ describes the dichotomous *observed* outcome -->
#
# <!-- Following what it is stated by the DAG, we can transform it into an SCM, in the following way -->
# <!-- $$ -->
# <!-- \begin{aligned}[t] -->
# <!--   O_{kijr_{ij}} := & \; f_{O}( \delta_{kijr_{ij}} ) \\ -->
# <!--   \delta_{kijr_{ij}} := & \; f_{D}( \gamma_{k}, \theta_{ir_{i}} ) \\ -->
# <!--   \gamma_{k} := & \; f_{G}( Z_{k}, e_{k} ) \\ -->
# <!--   \theta_{ir_{i}} := & \; f_{R}( \theta_{i}, Y_{r}, e_{r_{i}} ) \\ -->
# <!--   \theta_{i} := & \; f_{T}( X_{i}, e_{i} ) \\ -->
# <!--   & \; \dsep{e_{k}}{e_{i}} \\ -->
# <!--   & \; \dsep{e_{k}}{e_{r_{i}}} \\ -->
# <!--   & \; \dsep{e_{i}}{e_{r_{i}}} -->
# <!-- \end{aligned} -->
# <!-- $$ {#eq-StructuralModel} -->
#
#
#
# ### From the scientific to the statistical DCJ model {#sec-Sci2StatMod}
#
# <!-- "An appropriate analysis of data cannot be completed without knowledge of what experimental design was used and how the data was collected, and conclusions are not reliable if they are not justified by the proper modeling and analysis of the data" [see @Lawson_2015, pp. 7] -->
#
# <!-- It is more likely that we can decide the characteristics of the objects we want to include in the study (independent variables), ensuring groups that are more balanced. However, in the case of subjects sometimes the independent variables cannot be assigned (e.g., hearing status). -->
#
# <!-- "In many cases where observational units are different than the experimental units, the observational units will not be independent" [see @Lawson_2015, pp. 177] -->
#
# <!-- 3. Considering the predictability of the phenomena -->
# <!--       its importance in @Shmueli_et_al_2011 and Lawson [-@Lawson_2015, pp. 7] -->
#
# <!-- Bayesian Bradley-Terry-Luce model (BTL) [@Bradley_et_al_1952, @Luce_1959, @Pollitt_2012b, @BradleyTerry2_2012]  -->
#
# <!-- $$ -->
# <!-- \begin{aligned}[t] -->
# <!--   O_{kijr_{ij}} \sim & \; \text{Bernoulli}\left[ \; \text{inv}\_\text{logit}\left( \delta_{kijr_{ij}} \right) \; \right] \\ -->
# <!--   \delta_{kijr_{ij}} = & \; \gamma_{k}( \theta_{ir_{i}} - \theta_{jr_{j}} ) \\ -->
# <!--   \gamma_{k} \sim & \; \text{Log-Normal}( \beta_{Z} Z_{k},\; \sigma_{k} ) \\ -->
# <!--   \theta_{ir_{i}} \sim & \; \text{Normal}( \theta_{i} + \beta_{Y} Y_{r},\; \sigma_{r_{i}} )  \\ -->
# <!--   \theta_{i} \sim & \; \text{Normal}( \beta_{X} X_{i},\; \sigma_{i}) \\ -->
# <!--   \sigma_{k} = & \; 1/10 \\ -->
# <!--   \sigma_{i} = & \; 1 \\ -->
# <!--   \sigma_{r_{i}} \sim & \; \text{Exponential}(2) -->
# <!-- \end{aligned} -->
# <!-- $$ {#eq-StatisticalModel1} -->
#
#
# <!-- $$ -->
# <!-- \begin{aligned}[t] -->
# <!--   O_{kijr_{ij}} \sim & \; \text{Bernoulli}\left[ \; \text{inv}\_\text{logit}\left( \delta_{kijr_{ij}} \right) \; \right] \\ -->
# <!--   \delta_{kijr_{ij}} = & \; \gamma_{k}( \theta_{ir_{i}} - \theta_{jr_{j}} ) \\ -->
# <!--   \gamma_{k} = & \; exp\left(\beta_{Z} Z_{k} + e_{k} \right) \\ -->
# <!--   \theta_{ir_{i}} = & \; \theta_{i} + \beta_{Y} Y_{r} + e_{r_{i}}  \\ -->
# <!--   \theta_{i} = & \; \beta_{X} X_{i} + e_{i}  \\ -->
# <!--   e_{k} \sim & \; \text{Normal}(0, 1/10) \\ -->
# <!--   e_{i} \sim & \; \text{Normal}(0, 1) \\ -->
# <!--   e_{r_{i}} \sim & \; \text{Normal}(0, \sigma_{r_{i}}) \\ -->
# <!--   \sigma_{r_{i}} \sim & \; \text{Exponential}(2) -->
# <!-- \end{aligned} -->
# <!-- $$ {#eq-StatisticalModel2} -->
#
#
# ## Methods {#sec-methods}
#
# ### Bayesian simulation and power analysis
#
# <!-- "Power analysis is only useful when the simulated data imitate actual data ... We assume that the model is a reasonably good description of the actual data" [see @Kruschke_2015, pp. 394] -->
#
# <!-- In terms of the highest density interval (HDI), power can be expressed in three goals [@Kruschke_2015]: -->
#
# <!-- 1. **Reject a null value of a parameter** -->
#
# <!--     *Formal expression:* Show that a region of practical equivalence (ROPE) around the null value excludes the posterior $95\%$ HDI. -->
#
# <!-- 2. **Affirm a predicted value of a parameter** -->
#
# <!--     *Formal expression:* Show that a ROPE around the predicted value includes the posterior $95\%$ HDI. -->
#
# <!-- 3. **Achieve precision in the estimate of a parameter** -->
#
# <!--     *Formal expression:* Show that the posterior $95\%$ HDI has width less than a specified maximum. -->
#
#
# <!-- According to the definition of @Lawson_2015 -->
# <!-- In the context of DCJ -->
#
# <!-- Experiment:  -->
# <!-- present two objects coming from two subjects to a judge, who will assess which object among the two have a greater amount of the trait under assessment. If object A have more of the trait than B, then you score it with a 1, otherwise 0 -->
#
# <!-- Ideal scenario: -->
# <!-- all judges assess all pairs of subjects, with all pairs of objects, more than one time [see @Lawson_2015, pp. 262] (recipe example) -->
#
# <!-- Experimental unit:  -->
# <!-- Trials of the experiment, where a pair of subjects is rated by a judge using two pairs of objects [see @Lawson_2015, pp. 124] (GCB) -->
#
# <!-- Observational unit:  -->
# <!-- objects within subjects (they work as items in IRT?) -->
#
# <!-- Treatment variable:  -->
# <!-- Two subjects under comparison -->
#
# <!-- Independent variable: -->
# <!-- characteristics of the subjects or objects -->
#
# <!-- Background variable:  -->
# <!-- Unknown, it is subject-matter specific -->
#
# <!-- Blocking variable:  -->
# <!-- a. Judges? (In BIB) -->
# <!-- b. Block of day in which the experiment is performed -->
#
# <!-- Dependent variable (response):  -->
# <!-- dichotomous rating -->
#
# <!-- Effect:  -->
# <!-- 1. differences among individuals -->
# <!-- 2. changes in response by changing treatment factors -->
# <!-- 3. Changes in response by changing blocking variable -->
#
# <!-- Replicate runs:  -->
# <!-- experiments where either one or two of the subjects in the pair is different. Best case scenario is when all pairs of subjects are compaired with all pairs of objects at least by one judge (one block) -->
#
# <!-- Duplicate runs:  -->
# <!-- experiments where the same judge compares the same two subjects more than one time. Best case scenario is when all judges assess the same pair of subjects more than one time (with different or the same objects) -->
# <!-- e.g., If the measured response changes with the objects, then the response is varying due to measurement error, and therefore, objects constitute duplicate runs.  -->
# <!-- If the same judge assess the same two objects from the same two subjects more than one time, then the variability of the assessment of the judge can be partitioned additionally into variance between pairs of objects and variance within pairs of objects. -->
#
# <!-- From @Lawson_2015, another way to see DCJ experiments I'd that you are grouping heterogeneous experimental units (objects and subjects) into homogeneous ones (judges), which are your "blocks". In that case if you expect that blocking will reduce the variance of EUs within blocks by a percentage equal to $100*\left(1-\frac{1}{RE}\right)$ where $RE$ is the relative efficiency in respect to a CRD  then the replicates would be $r=r_{crd}/RE$ and the number of blocks of size $k$ would be $b=tr/k$ [see @Lawson_2015, pp. 121-122, pp. 267] -->
#
# <!-- Usually, in these types of experiments the objects are observational units from higher hierarchical levels, such as subjects. For example, when researchers are interested in assessing the trait of speech intelligibility of individuals (subjects), judges rate dichotomously two uttered sentences (objects, nested within individuals). -->
#
#
# <!-- Generate random data up until judges and subjects abilities. Then for the population assume you made all comparisons. Then sample with BIB [@Lawson_2015] the pairs compared. -->
# <!-- For effect size test, simulate individuals from the distribution, identify which have a desired difference and calculate power on those individuals. -->
# <!-- Track the total number of comparison per subjects as another representation -->
# <!-- Steps: -->
# <!-- 1. Define parameters generating the population, by factorial design -->
# <!-- 2. Generate a population: 500 subjects, 100 objects and all comparisons made 100 times -->
# <!-- 3. Sample from population with BIB -->
# <!-- 4. Run model on the sample -->
# <!-- 5. Report the goals -->
# <!-- 6. Repeat steps 3-5 for a specific number of simulations. -->
# <!-- 7. Repeat steps 1-6 for all parameters combinations -->
#
#
#
# ## Results {#sec-results}
#
# ### Research question 1 {#sec-RQ1}
#
# ### Research question 2 {#sec-RQ2}
#
# ### Research question 3 {#sec-RQ3}
#
#
#
# ## Discussion {#sec-discussion}
#
# <!-- When you want to investigate objects, the experiment has an experimental unit: the trial on the objects, but you only have one object per subject. Consequently, objects and subjects are confounded. -->
#
# ### Limitations and further research {#sec-LFR}
#
# <!-- We are trying to do prospective power analysis, however, you should pose the possibility that other authors perform replication power [see @Kruschke_2015, pp. 393]. The next paper is going to perform retrospective power analysis -->
#
# <!-- The study only compared the reliability coefficients between the adaptive and non-adaptive studies, without considering other aspects of validity or the impact on external variables -->
#
# <!-- Prospect of future research: -->
#
# <!-- - Does the pairing algorithm have an impact on any of the three research questions? -->
# <!-- - What is the maximum of comparisons per judge to avoid loosing discrimination ability?, is it task-specific? (most likely) -->
#
#
# ## Conclusion {#sec-conclusion}
#
#
# ## References {.unnumbered}
#
# :::{#refs}
#
# :::
# ````
