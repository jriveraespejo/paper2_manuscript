# %% [markdown]
# # Data simulation
#
# Jose Manuel Rivera Espejo
#
# Assuming the This notebook guides the reader through the data simulation process

# %% [raw]
# <!-- -->

# %% [markdown]
# ``` markdown
# ---
# title: Data simulation
# author: Jose Manuel Rivera Espejo
# ---
#
# Assuming the This notebook guides the reader through the data simulation process
# ```
